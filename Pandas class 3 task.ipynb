# %%
# FITBIT
1. Read this dataset in pandas, mysql, and mongodb
2.while creating a table in mysql do not use manual approach to create it, always use a automation to create a table in mysql
##hint -use csvkit library to automate this task and to load a data in bulk in your mysql(import wizard)
3.convert all the dates available in dataset to timeformat in pandas and in mysql you have to convert it in date format
4.Find out in this data that how many unique id's you have 
5.which id is one of the active id that you have in whole dataset
6.how many of them have not logged there activity find out in terms of number of ids 
7.Find out who is laziest person id that we have in dataset
8.Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy persons we have in our dataset
9.how many person are not a regular person with respect to activity try to find out those
10.who is the third most active person in this dataset find out those
11.who is the 5th most laziest person available in dataset and find it out
12.what is a total accumulative calories burn for a person and find out

# %% [markdown]
# ## Question 1

# %%
pip install csvkit
# Out:
# ...
#
# ...
#      -------------------------------------- 42.5/42.5 kB 414.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 97.1/97.1 kB 5.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 41.7/41.7 kB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 42.5/42.5 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 112.2/112.2 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35472 sha256=2f260757a125fa683809d199f7d751347654de025ee81300c284d7f76762131e
#   Stored in directory: c:\users\prince\appdata\local\pip\cache\wheels\4d\df\7b\24b97ee860e26da4f0b8867775ee4d94a5e8a0d173484ee74c
# Successfully built olefile
# ...

# %%
pip install mysqlclient
# Out:
# ...
#      -------------------------------------- 199.9/199.9 kB 3.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x25f89b34760>
# C:\Users\Prince\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=3>
# C:\Users\Prince\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=4>
# C:\Users\Prince\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>

# %%
import pymongo
import pandas as pd
import json
import csvkit
import mysql.connector as conn
import MySQLdb
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Prince\Downloads\FitBit data.csv')

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://princefrancis64:Oejb2e2l74Gz4NAK@cluster0.o5qm0dq.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
df.shape
# Out:
# (457, 15)

# %%
data = df.to_dict(orient = 'records')

# %%
data
# Out:
# [{'Id': 1503960366,
#   'ActivityDate': '3/25/2016',
#   'TotalSteps': 11004,
#   'TotalDistance': 7.1100001335144,
#   'TrackerDistance': 7.1100001335144,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 2.5699999332428,
#   'ModeratelyActiveDistance': 0.46000000834465,
#   'LightActiveDistance': 4.07000017166138,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 33,
#   'FairlyActiveMinutes': 12,
#   'LightlyActiveMinutes': 205,
#   'SedentaryMinutes': 804,
#   'Calories': 1819},
#  {'Id': 1503960366,
#   'ActivityDate': '3/26/2016',
#   'TotalSteps': 17609,
#   'TotalDistance': 11.5500001907349,
#   'TrackerDistance': 11.5500001907349,
#   'LoggedActivitiesDistance': 0.0,
#   'VeryActiveDistance': 6.92000007629395,
#   'ModeratelyActiveDistance': 0.730000019073486,
#   'LightActiveDistance': 3.91000008583069,
#   'SedentaryActiveDistance': 0.0,
#   'VeryActiveMinutes': 89,
#   'FairlyActiveMinutes': 17,
#   'LightlyActiveMinutes': 274,
# ...

# %%
db = client['ineuron']

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-ti6bzi3-shard-00-02.o5qm0dq.mongodb.net:27017', 'ac-ti6bzi3-shard-00-00.o5qm0dq.mongodb.net:27017', 'ac-ti6bzi3-shard-00-01.o5qm0dq.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-287kn6-shard-0', tls=True), 'ineuron')

# %%
db.tasks.insert_many(data)

# %%
# !csvsql --db mysql://root:Letsgo1247@localhost:3306/ineuron --insert FitBit.csv
# Out:
# C:\Users\Prince\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=3>
# C:\Users\Prince\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=4>
# C:\Users\Prince\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>

# %% [markdown]
# ## Question 3

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391   04-08-2016       23014      20.389999        20.389999
# 453  8877689391   04-09-2016       16470       8.070000         8.070000
# 454  8877689391   04-10-2016       28497      27.530001        27.530001
# 455  8877689391   04-11-2016       10622       8.060000         8.060000
# 456  8877689391   04-12-2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df.ActivityDate = pd.to_datetime(df.ActivityDate)

# %%
df.dtypes
# Out:
# Id                                   int64
# ActivityDate                datetime64[ns]
# TotalSteps                           int64
# TotalDistance                      float64
# TrackerDistance                    float64
# LoggedActivitiesDistance           float64
# VeryActiveDistance                 float64
# ModeratelyActiveDistance           float64
# LightActiveDistance                float64
# SedentaryActiveDistance            float64
# VeryActiveMinutes                    int64
# FairlyActiveMinutes                  int64
# LightlyActiveMinutes                 int64
# SedentaryMinutes                     int64
# Calories                             int64
# dtype: object

# %% [markdown]
# ## Question4

# %%
# 4.Find out in this data that how many unique id's you have 
s  = df.Id.unique()

# %%
df.Id.unique()
# Out:
# array([1503960366, 1624580081, 1644430081, 1844505072, 1927972279,
#        2022484408, 2026352035, 2320127002, 2347167796, 2873212765,
#        2891001357, 3372868164, 3977333714, 4020332650, 4057192912,
#        4319703577, 4388161847, 4445114986, 4558609924, 4702921684,
#        5553957443, 5577150313, 6117666160, 6290855005, 6391747486,
#        6775888955, 6962181067, 7007744171, 7086361926, 8053475328,
#        8253242879, 8378563200, 8583815059, 8792009665, 8877689391],
#       dtype=int64)

# %%
len(s)
# Out:
# 35

# %% [markdown]
# ## Question 5

# %%
#5.which id is one of the active id that you have in whole dataset

# %%
df.groupby('Id')['TotalDistance','Calories'].mean().sort_values(by = 'TotalDistance',ascending= False)
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_13384\1603515137.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#             TotalDistance     Calories
# Id
# 8877689391      14.090833  3451.166667
# 8053475328      11.576364  2893.181818
# 7007744171       8.856667  2627.083333
# 2022484408       8.774167  2475.333333
# 6962181067       8.647857  2089.214286
# 1503960366       7.607368  1796.210526
# 1644430081       6.749000  2916.400000
# 2347167796       6.511333  2021.333333
# 8378563200       6.451667  3356.166667
# 5577150313       6.448182  3300.272727
# 4702921684       6.446000  2821.466667
# 6117666160       6.227000  2099.300000
# 3977333714       5.806667  1398.083333
# 5553957443       5.458333  1802.500000
# 4319703577       5.255833  1994.250000
# 2873212765       4.469167  1695.750000
# 3372868164       4.216000  1860.300000
# 4020332650       4.143750  3075.375000
# ...

# %% [markdown]
# ## Question 6

# %%
# 6.how many of them have not logged there activity find out in terms of number of ids

# %%
df.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   2016-03-25       11004           7.11             7.11
# 1  1503960366   2016-03-26       17609          11.55            11.55
# 2  1503960366   2016-03-27       12736           8.53             8.53
# 3  1503960366   2016-03-28       13231           8.93             8.93
# 4  1503960366   2016-03-29       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
df.LoggedActivitiesDistance.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 452    False
# 453    False
# 454    False
# 455    False
# 456    False
# Name: LoggedActivitiesDistance, Length: 457, dtype: bool

# %%
df.shape
# Out:
# (457, 15)

# %%
len(df[df.LoggedActivitiesDistance!=0]['Id'].unique())
# Out:
# 6

# %%
len(df['Id'].unique())
# Out:
# 35

# %%
# there has been 29 Id's which has not been logged in

# %% [markdown]
# ## Question 7

# %%
#7.Find out who is laziest person id that we have in dataset

# %%
df.groupby('Id')['TotalDistance','Calories'].mean().sort_values(by = 'Calories',ascending= False).tail(1)
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_9244\2799968913.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Id')['TotalDistance','Calories'].mean().sort_values(by = 'Calories',ascending= False).tail(1)
#             TotalDistance     Calories
# Id
# 1624580081       2.746842  1352.894737

# %% [markdown]
# ## Question 8

# %%
# 8.Explore over an internet that how much calories burn is required for a healthy person and find out how many healthy persons we have in our dataset

# %%
# taking consideration of 2,000 calories burnt per day

# %%
df1 = df.groupby('Id').agg(np.mean)
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_13384\3200236356.py:1: FutureWarning: The operation <function mean at 0x000001FC6CF6C3A0> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.

# %%
len(df1[df1['Calories']>2000])
# Out:
# 20

# %%
def healthy(a):
    if a>2000:
        return 'healthy'
    else:
        return 'not healthy'

# %%
df1['health_status'] = df1['Calories'].apply(healthy)

# %%
df1
# Out:
#               TotalSteps  TotalDistance  TrackerDistance  \
# Id
# 1503960366  11640.526316       7.607368         7.607368
# 1624580081   4226.263158       2.746842         2.746842
# 1644430081   9274.800000       6.749000         6.749000
# 1844505072   3640.583333       2.406667         2.406667
# 1927972279   2180.833333       1.510833         1.510833
# 2022484408  12174.916667       8.774167         8.774167
# 2026352035   3392.750000       2.103333         2.103333
# 2320127002   3138.416667       2.122500         2.122500
# 2347167796   9800.066667       6.511333         6.511333
# 2873212765   6636.583333       4.469167         4.469167
# 2891001357    773.625000       0.603750         0.000000
# 3372868164   6127.500000       4.216000         4.216000
# 3977333714   8663.916667       5.806667         5.806667
# 4020332650   5776.593750       4.143750         4.143750
# 4057192912   1887.218750       1.389063         1.406875
# ...

# %%
len(df1[df1['health_status']=='healthy'])
# Out:
# 20

# %%
#Total of 20 people are healthy

# %% [markdown]
# ## Question 9

# %%
#9.how many person are not a regular person with respect to activity try to find out those

# %%
activity_level = df.groupby('Id').agg(np.mean)
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_13384\2207718424.py:1: FutureWarning: The operation <function mean at 0x000001FC6CF6C3A0> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.

# %%
len(activity_level[activity_level['TotalDistance']>3])  #suppose we take into consideration the distance of 3
# Out:
# 21

# %%
#14 people are not a regular activity person

# %% [markdown]
# ## Question 10

# %%
# 10.who is the third most active person in this dataset find out those

# %%
active = df.groupby('Id')['TotalDistance','Calories'].mean().sort_values(by = 'TotalDistance',ascending= False)
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_13384\2671102511.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
active
# Out:
#             TotalDistance     Calories
# Id
# 8877689391      14.090833  3451.166667
# 8053475328      11.576364  2893.181818
# 7007744171       8.856667  2627.083333
# 2022484408       8.774167  2475.333333
# 6962181067       8.647857  2089.214286
# 1503960366       7.607368  1796.210526
# 1644430081       6.749000  2916.400000
# 2347167796       6.511333  2021.333333
# 8378563200       6.451667  3356.166667
# 5577150313       6.448182  3300.272727
# 4702921684       6.446000  2821.466667
# 6117666160       6.227000  2099.300000
# 3977333714       5.806667  1398.083333
# 5553957443       5.458333  1802.500000
# 4319703577       5.255833  1994.250000
# 2873212765       4.469167  1695.750000
# 3372868164       4.216000  1860.300000
# 4020332650       4.143750  3075.375000
# 7086361926       4.094167  2177.000000
# 6775888955       3.985556  2724.777778
# 4558609924       3.823333  1830.166667
# 4445114986       2.906667  2107.800000
# 1624580081       2.746842  1352.894737
# ...

# %%
# 7007744171 will be the 3rd most active person

# %% [markdown]
# ## Question 11

# %%
#11.who is the 5th most laziest person available in dataset and find it out

# %%
active = df.groupby('Id')['TotalDistance','Calories'].mean().sort_values(by = 'TotalDistance',ascending= True)
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_13384\63690505.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %%
active
# Out:
#             TotalDistance     Calories
# Id
# 4388161847       0.000000  1805.250000
# 2891001357       0.603750  2273.375000
# 6391747486       1.074444  1763.111111
# 6290855005       1.223000  2165.600000
# 4057192912       1.389063  1903.531250
# 1927972279       1.510833  2254.000000
# 8253242879       1.679167  1463.000000
# 8792009665       1.980833  2073.666667
# 2026352035       2.103333  1355.500000
# 2320127002       2.122500  1532.083333
# 8583815059       2.377500  2391.250000
# 1844505072       2.406667  1615.916667
# 1624580081       2.746842  1352.894737
# 4445114986       2.906667  2107.800000
# 4558609924       3.823333  1830.166667
# 6775888955       3.985556  2724.777778
# 7086361926       4.094167  2177.000000
# 4020332650       4.143750  3075.375000
# 3372868164       4.216000  1860.300000
# 2873212765       4.469167  1695.750000
# 4319703577       5.255833  1994.250000
# 5553957443       5.458333  1802.500000
# 3977333714       5.806667  1398.083333
# ...

# %%
#4057192912 will the 5th most laziest person

# %% [markdown]
# ## Question 12

# %%
# 12.what is a total accumulative calories burn for a person and find out

# %%
df.groupby('Id')['TotalDistance','Calories'].mean().sort_values(by = 'Calories')
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_9244\2330452391.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Id')['TotalDistance','Calories'].mean().sort_values(by = 'Calories')
#             TotalDistance     Calories
# Id
# 1624580081       2.746842  1352.894737
# 2026352035       2.103333  1355.500000
# 3977333714       5.806667  1398.083333
# 8253242879       1.679167  1463.000000
# 2320127002       2.122500  1532.083333
# 1844505072       2.406667  1615.916667
# 2873212765       4.469167  1695.750000
# 6391747486       1.074444  1763.111111
# 1503960366       7.607368  1796.210526
# 5553957443       5.458333  1802.500000
# 4388161847       0.000000  1805.250000
# 4558609924       3.823333  1830.166667
# 3372868164       4.216000  1860.300000
# 4057192912       1.389063  1903.531250
# 4319703577       5.255833  1994.250000
# 2347167796       6.511333  2021.333333
# ...

# %%
#task 2 -Superstore_USA
1.load this data in sql and in pandas with a relation in sql
2.while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table 
3.Find out how many return that we have receied and with a product id
4.try to join order and return data both in sql and pandas
5.try to find out how many unique customer that we have
6.try to find out in how many regions we are selling a product and who is the manager of respective region
7.find out how many different shipment mode that we have and what is a percentage usability of all the segment
8.Create a new column and try to find out a difference between order date and shipment date
9. based on question number 8 find out for which order id we hvae shipment duration more than 10 days
10.try to find out a list of a returned order which shipment duration was more than 15 days and find out that region manager as well
11.Group by region and find out which region is more profitable 
12.Try to find out overall in which country we are giving more discount 
13.Give me a list of unique postal code 
14.which customer segment is more profitable find out
15.try to find out the 10the most loss making product category.
16.try to find out the product with most margins
17.try to find out 10 top product with highest margins

# %% [markdown]
# ## Question 1

# %%
df2 = pd.read_excel(r'C:\Users\Prince\Downloads\Superstore_USA.xlsx')

# %%
df2.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %% [markdown]
# ## Question 3

# %%
#3.Find out how many return that we have receied and with a product id

# %%
df3 = pd.read_excel(r'C:\Users\Prince\Downloads\Superstore_USA.xlsx',sheet_name = 'Returns')

# %%
df3
# Out:
#       Order ID    Status
# 0           65  Returned
# 1          612  Returned
# 2          614  Returned
# 3          678  Returned
# 4          710  Returned
# ...        ...       ...
# 1629    182681  Returned
# 1630    182683  Returned
# 1631    182750  Returned
# 1632    182781  Returned
# 1633    182906  Returned
#
# [1634 rows x 2 columns]

# %%
df3.groupby('Order ID')['Order ID'].count()
# Out:
# Order ID
# 65        1
# 612       1
# 614       1
# 678       1
# 710       1
#          ..
# 182681    1
# 182683    1
# 182750    1
# 182781    1
# 182906    1
# Name: Order ID, Length: 1634, dtype: int64

# %% [markdown]
# ## Question 4

# %%
# 4.try to join order and return data both in sql and pandas

# %%
df4 = pd.merge(df2,df3,how = 'left')

# %%
df4
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df4.Status.unique()
# Out:
# array([nan, 'Returned'], dtype=object)

# %% [markdown]
# ## Question 5

# %%
# 5.try to find out how many unique customer that we havex

# %%
df2.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
len(df2['Customer Name'].unique())
# Out:
# 2703

# %% [markdown]
# ## Question 6

# %%
# 6.try to find out in how many regions we are selling a product and who is the manager of respective region

# %%
df5 = pd.read_excel(r'C:\Users\Prince\Downloads\Superstore_USA.xlsx',sheet_name = 'Users')

# %%
man = df2[['Product Name' ,'Region']]

# %%
combined = pd.merge(man,df5,how = 'left')

# %%
combined
# Out:
#                                            Product Name   Region  Manager
# 0                                              Avery 49  Central    Chris
# 1        SANFORD Liquid Accent™ Tank-Style Highlighters     West  William
# 2                                            Xerox 1968     West  William
# 3              Acme® Preferred Stainless Steel Scissors     West  William
# 4                                                   V70     West  William
# ...                                                 ...      ...      ...
# 9421      Jet-Pak Recycled Peel 'N' Seal Padded Mailers     East     Erin
# 9422       Eldon Spacemaker® Box, Quick-Snap Lid, Clear     East     Erin
# 9423  Chromcraft Bull-Nose Wood Oval Conference Tabl...     East     Erin
# 9424  Tenex 46" x 60" Computer Anti-Static Chairmat,...     West  William
# 9425                      Staples #10 Colored Envelopes     West  William
#
# [9426 rows x 3 columns]

# %% [markdown]
# ## Question 7

# %%
# 7.find out how many different shipment mode that we have and what is a percentage usability of all the segment

# %%
perc = df2.groupby(['Ship Mode'])['Ship Mode','Quantity ordered new'].sum()
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_13384\1093814484.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# C:\Users\Prince\AppData\Local\Temp\ipykernel_13384\1093814484.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
perc
# Out:
#                 Quantity ordered new
# Ship Mode
# Delivery Truck                 16802
# Express Air                    15056
# Regular Air                    98206

# %%
total = perc.sum()

# %%
perc['Percentage Share'] = (perc/total)*100

# %%
perc
# Out:
#                 Quantity ordered new  Percentage Share
# Ship Mode
# Delivery Truck                 16802         12.918256
# Express Air                    15056         11.575840
# Regular Air                    98206         75.505905

# %% [markdown]
# ## Question 8

# %%
# 8.Create a new column and try to find out a difference between order date and shipment date

# %%
df2.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
df2['days_took_to_ship'] = df2['Ship Date'] - df2['Order Date']

# %%
df2[['days_took_to_ship']]
# Out:
#      days_took_to_ship
# 0               2 days
# 1               1 days
# 2               1 days
# 3               1 days
# 4               0 days
# ...                ...
# 9421            1 days
# 9422            0 days
# 9423            2 days
# 9424            3 days
# 9425            2 days
#
# [9426 rows x 1 columns]

# %% [markdown]
# ## Question 9

# %%
# 9. based on question number 8 find out for which order id we hvae shipment duration more than 10 days

# %%
df2.dtypes
# Out:
# Row ID                            int64
# Order Priority                   object
# Discount                        float64
# Unit Price                      float64
# Shipping Cost                   float64
# Customer ID                       int64
# Customer Name                    object
# Ship Mode                        object
# Customer Segment                 object
# Product Category                 object
# Product Sub-Category             object
# Product Container                object
# Product Name                     object
# Product Base Margin             float64
# Region                           object
# State or Province                object
# City                             object
# Postal Code                       int64
# Order Date               datetime64[ns]
# Ship Date                datetime64[ns]
# Profit                          float64
# Quantity ordered new              int64
# Sales                           float64
# ...

# %%
df2.head(3)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date Profit  \
# 0          Illinois    Addison       60101  2012-05-28 2012-05-30   1.32
# 1        Washington  Anacortes       98221  2010-07-07 2010-07-08   4.56
# 2        Washington  Anacortes       98221  2011-07-27 2011-07-28 -47.64
#
#   Quantity ordered new  Sales Order ID days_took_to_ship
# ...

# %%
converting timeformat into int

# %%
df2['days_took_to_ship_str'] = df2['days_took_to_ship'].astype(str)

# %%
df2['days_took_to_ship_int'] = df2['days_took_to_ship_str'].str.replace("days",'')

# %%
df2['days_took_to_ship_int']=df2['days_took_to_ship_int'].astype(int)

# %%
df2[['days_took_to_ship_int']]
# Out:
#       days_took_to_ship_int
# 0                         2
# 1                         1
# 2                         1
# 3                         1
# 4                         0
# ...                     ...
# 9421                      1
# 9422                      0
# 9423                      2
# 9424                      3
# 9425                      2
#
# [9426 rows x 1 columns]

# %%
df2[df2['days_took_to_ship_int']>10][['Order ID']]
# Out:
#       Order ID
# 643      87215
# 1548     86318
# 1549     86318
# 1678     87957
# 1679     87957
# 1680     87957
# 1697     19556
# 1698     19556
# 1699     19556
# 2515     86177
# 5548     88223
# 5673     88352
# 5859     87572
# 5881     91294
# 8607     86434
# 8609     86436
# 8610     86436
# 8973     87300
# 8982     19841
# 8983     19841
# 8993     19841
# 8996     87300
# 8997     87300

# %% [markdown]
# ## Question 10

# %%
# 10.try to find out a list of a returned order which shipment duration was more than 15 days and find out that region manager as well

# %%
delayed = df2[df2['days_took_to_ship_int']>15]

# %%
delayed
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5673   19005            Low      0.06       65.99           2.50         2088
# 5859   24392            Low      0.05       29.89           1.99         2143
# 5881   21257            Low      0.05        7.99           5.03         2153
# 8607   26351         Medium      0.00        8.32           2.38         3119
# 8609   26350         Medium      0.07      180.98          55.24         3119
# ...

# %%
pd.merge(delayed,df3,how = 'inner')
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, days_took_to_ship, days_took_to_ship_converted, days_took_to_ship_str, days_took_to_ship_int, Status]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ## Question 11

# %%
# 11.Group by region and find out which region is more profitable

# %%
df2.dtypes
# Out:
# Row ID                                   int64
# Order Priority                          object
# Discount                               float64
# Unit Price                             float64
# Shipping Cost                          float64
# Customer ID                              int64
# Customer Name                           object
# Ship Mode                               object
# Customer Segment                        object
# Product Category                        object
# Product Sub-Category                    object
# Product Container                       object
# Product Name                            object
# Product Base Margin                    float64
# Region                                  object
# State or Province                       object
# City                                    object
# Postal Code                              int64
# Order Date                      datetime64[ns]
# Ship Date                       datetime64[ns]
# ...

# %%
df2.groupby('Region')['Profit'].sum()
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# South      104201.192420
# West       310849.453897
# Name: Profit, dtype: float64

# %%
#central region is more profitable

# %% [markdown]
# ## Question 12

# %%
# 12.Try to find out overall in which country we are giving more discount

# %%
df2.groupby('State or Province')['Discount'].sum().sort_values(ascending = False)
# Out:
# State or Province
# California              52.28
# Texas                   31.36
# Illinois                29.71
# New York                28.86
# Florida                 26.38
# Ohio                    19.71
# Washington              15.48
# Michigan                15.29
# Pennsylvania            13.32
# Minnesota               12.52
# Indiana                 12.22
# North Carolina          12.02
# Massachusetts           11.22
# Virginia                 9.80
# Georgia                  9.79
# Maryland                 8.85
# New Jersey               8.73
# Tennessee                8.55
# Oregon                   8.42
# Missouri                 8.09
# Wisconsin                8.06
# Colorado                 8.05
# Utah                     7.67
# Iowa                     7.15
# Kansas                   6.89
# Arizona                  6.86
# Maine                    6.66
# Alabama                  5.87
# Arkansas                 5.80
# Idaho                    5.57
# ...

# %%
# In california we are giving more discount

# %% [markdown]
# ## Question 13

# %%
# 13.Give me a list of unique postal code

# %%
df2['Postal Code'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %% [markdown]
# ## Question 14

# %%
# 14.which customer segment is more profitable find out

# %%
df2.groupby('Customer Segment')['Profit'].sum().sort_values()
# Out:
# Customer Segment
# Consumer          206559.625348
# Home Office       283869.553814
# Small Business    316474.592482
# Corporate         505538.627783
# Name: Profit, dtype: float64

# %%
# clearly Corporate is more profitable

# %% [markdown]
# ## Question 15

# %%
# 15.try to find out the 10the most loss making product category.

# %%
df2.dtypes
# Out:
# Row ID                                   int64
# Order Priority                          object
# Discount                               float64
# Unit Price                             float64
# Shipping Cost                          float64
# Customer ID                              int64
# Customer Name                           object
# Ship Mode                               object
# Customer Segment                        object
# Product Category                        object
# Product Sub-Category                    object
# Product Container                       object
# Product Name                            object
# Product Base Margin                    float64
# Region                                  object
# State or Province                       object
# City                                    object
# Postal Code                              int64
# Order Date                      datetime64[ns]
# Ship Date                       datetime64[ns]
# ...

# %%
df2.groupby('Product Category')

# %%
df2.groupby('Product Category')['Profit'].sum()
# Out:
# Product Category
# Furniture          177354.298188
# Office Supplies    451990.216492
# Technology         683097.884748
# Name: Profit, dtype: float64

# %%
#there is no loss in the Product category

# %% [markdown]
# ## Question 16

# %%
# 16.try to find out the product with most margins

# %%
df2[['Product Sub-Category','Product Base Margin']].sort_values('Product Base Margin',ascending  = False)
# Out:
#               Product Sub-Category  Product Base Margin
# 9145  Telephones and Communication                 0.85
# 4756  Telephones and Communication                 0.85
# 7607  Telephones and Communication                 0.85
# 5672  Telephones and Communication                 0.85
# 4168                  Rubber Bands                 0.85
# ...                            ...                  ...
# 8986            Chairs & Chairmats                  NaN
# 9005                        Tables                  NaN
# 9352            Chairs & Chairmats                  NaN
# 9378        Storage & Organization                  NaN
# 9393            Chairs & Chairmats                  NaN
#
# [9426 rows x 2 columns]

# %%
df2.dtypes
# Out:
# Row ID                                   int64
# Order Priority                          object
# Discount                               float64
# Unit Price                             float64
# Shipping Cost                          float64
# Customer ID                              int64
# Customer Name                           object
# Ship Mode                               object
# Customer Segment                        object
# Product Category                        object
# Product Sub-Category                    object
# Product Container                       object
# Product Name                            object
# Product Base Margin                    float64
# Region                                  object
# State or Province                       object
# City                                    object
# Postal Code                              int64
# Order Date                      datetime64[ns]
# Ship Date                       datetime64[ns]
# ...

# %% [markdown]
# ## Question 17

# %%
# 17.try to find out 10 top product with highest margins

# %%
margins = df2[['Product Sub-Category','Product Base Margin']].sort_values('Product Base Margin',ascending  = False)

# %%
margins.iloc[:10]
# Out:
#               Product Sub-Category  Product Base Margin
# 9145  Telephones and Communication                 0.85
# 4756  Telephones and Communication                 0.85
# 7607  Telephones and Communication                 0.85
# 5672  Telephones and Communication                 0.85
# 4168                  Rubber Bands                 0.85
# 807   Telephones and Communication                 0.85
# 816   Telephones and Communication                 0.85
# 3994        Storage & Organization                 0.85
# 2138                  Rubber Bands                 0.85
# 7202        Storage & Organization                 0.85

# %%
df3 = pd.read_csv('SuperStoreUsa.csv',delimiter= ',')

# %%
df3
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
# !csvsql --db mysql://root:Letsgo1247@localhost:3306/ineuron --insert SuperStoreUsa.csv
# Out:
# C:\Users\Prince\anaconda3\lib\site-packages\agate\table\from_csv.py:70: RuntimeWarning: Error sniffing CSV dialect: Could not determine delimiter
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x1fc7859ece0>
# C:\Users\Prince\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=3>
# C:\Users\Prince\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=4>
# C:\Users\Prince\anaconda3\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>

# %%
df4 = df3.to_dict(orient = 'records')

# %%
df4
# Out:
# [{'Row ID': 18606,
#   'Order Priority': 'Not Specified',
#   'Discount': 0.01,
#   'Unit Price': 2.88,
#   'Shipping Cost': 0.5,
#   'Customer ID': 2,
#   'Customer Name': 'Janice Fletcher',
#   'Ship Mode': 'Regular Air',
#   'Customer Segment': 'Corporate',
#   'Product Category': 'Office Supplies',
#   'Product Sub-Category': 'Labels',
#   'Product Container': 'Small Box',
#   'Product Name': 'Avery 49',
#   'Product Base Margin': 0.36,
#   'Region': 'Central',
#   'State or Province': 'Illinois',
#   'City': 'Addison',
#   'Postal Code': 60101,
#   'Order Date': '28-05-2012',
#   'Ship Date': '30-05-2012',
#   'Profit': 1.32,
#   'Quantity ordered new': 2,
#   'Sales': 5.9,
#   'Order ID': 88525},
#  {'Row ID': 20847,
#   'Order Priority': 'High',
#   'Discount': 0.01,
#   'Unit Price': 2.84,
#   'Shipping Cost': 0.93,
#   'Customer ID': 3,
#   'Customer Name': 'Bonnie Potter',
#   'Ship Mode': 'Express Air',
#   'Customer Segment': 'Corporate',
# ...

# %%
from pymongo.mongo_client import MongoClient

uri = "mongodb+srv://princefrancis64:Oejb2e2l74Gz4NAK@cluster0.o5qm0dq.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
db= client['ineuron']

# %%
db.tasks.insert_many(df4)
