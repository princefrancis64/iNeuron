# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:/Users/Prince/Downloads/sales_data_final.csv")

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Dra        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df['order_id']
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df['order_date']
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
#             ...
# 51285    12/31/2014
# 51286    12/31/2014
# 51287    12/31/2014
# 51288    12/31/2014
# 51289    12/31/2014
# Name: order_date, Length: 51290, dtype: object

# %%
type(df['order_id'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df['profit'],df['year']
# Out:
# (0        106.1400
#  1         36.0360
#  2         29.6400
#  3        -26.0550
#  4         37.7700
#             ...
#  51285      4.5188
#  51286      0.4200
#  51287     12.3600
#  51288      0.5600
#  51289     -0.6048
#  Name: profit, Length: 51290, dtype: float64,
#  0        2011
#  1        2011
#  2        2011
#  3        2011
#  4        2011
#           ...
#  51285    2014
#  51286    2014
#  51287    2014
#  51288    2014
#  51289    2014
#  Name: year, Length: 51290, dtype: int64)

# %%
df[['profit','year']]
# Out:
#          profit  year
# 0      106.1400  2011
# 1       36.0360  2011
# 2       29.6400  2011
# 3      -26.0550  2011
# 4       37.7700  2011
# ...         ...   ...
# 51285    4.5188  2014
# 51286    0.4200  2014
# 51287   12.3600  2014
# 51288    0.5600  2014
# 51289   -0.6048  2014
#
# [51290 rows x 2 columns]

# %%
type(df[['profit']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['profit']]
# Out:
#          profit
# 0      106.1400
# 1       36.0360
# 2       29.6400
# 3      -26.0550
# 4       37.7700
# ...         ...
# 51285    4.5188
# 51286    0.4200
# 51287   12.3600
# 51288    0.5600
# 51289   -0.6048
#
# [51290 rows x 1 columns]

# %%
type(df['profit'])
# Out:
# pandas.core.series.Series

# %%
df['profit']
# Out:
# 0        106.1400
# 1         36.0360
# 2         29.6400
# 3        -26.0550
# 4         37.7700
#            ...
# 51285      4.5188
# 51286      0.4200
# 51287     12.3600
# 51288      0.5600
# 51289     -0.6048
# Name: profit, Length: 51290, dtype: float64

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df[['order_id','product_id','quantity']]
# Out:
#               order_id        product_id  quantity
# 0         AG-2011-2040  OFF-TEN-10000025         2
# 1        IN-2011-47883   OFF-SU-10000618         3
# 2         HU-2011-1220  OFF-TEN-10001585         4
# 3      IT-2011-3647632   OFF-PA-10001492         3
# 4        IN-2011-47883   FUR-FU-10003447         5
# ...                ...               ...       ...
# 51285   CA-2014-115427   OFF-BI-10002103         2
# 51286     MO-2014-2560  OFF-WIL-10001069         1
# 51287   MX-2014-110527   OFF-LA-10004182         3
# 51288   MX-2014-114783   OFF-LA-10000413         1
# 51289   CA-2014-156720   OFF-FA-10003472         3
#
# [51290 rows x 3 columns]

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
     df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.dtypes =='object'
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
type(df.dtypes =='object')
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes =='object']
# Out:
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_name     object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# order_priority    object
# dtype: object

# %%
df[df.dtypes[df.dtypes =='object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df[df.dtypes[df.dtypes=='float'].index].describe()
# Out:
#            discount        profit  shipping_cost
# count  51290.000000  51290.000000   51290.000000
# mean       0.142908     28.641740      26.375915
# std        0.212280    174.424113      57.296804
# min        0.000000  -6599.978000       0.000000
# 25%        0.000000      0.000000       2.610000
# 50%        0.000000      9.240000       7.790000
# 75%        0.200000     36.810000      24.450000
# max        0.850000   8399.976000     933.570000

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.order_id
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df['order_id'][1:40:2] #note series is like a list
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %%
 df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['category1'] = "prince"

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df['order_id'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: order_id, Length: 51290, dtype: bool

# %%
df1 = pd.read_csv(r"C:\Users\Prince\Downloads\data fsds -20230815T143451Z-001\data fsds\Dress Sales(1).csv")

# %%
df1
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1006032852        2114        2274        2491        2660        2727
# 1    1212192089         151         275         570         750         813
# 2    1190380701           6           7           7           7           8
# 3     966005983        1005        1128        1326        1455        1507
# 4     876339541         996        1175        1304        1396        1432
# ..          ...         ...         ...         ...         ...         ...
# 495   713391965           0           0           0         560         554
# 496   722565148           0           0           0         875         866
# 497   532874347           0           0           0         734         728
# 498   655464934           0           0           0         254         259
# 499   919930954           0           0           0         538         545
#
# ...

# %%
df1.columns
# Out:
# Index(['Dress_ID', '29-08-2013', '31-08-2013', '09-02-2013', '09-04-2013',
#        '09-06-2013', '09-08-2013', '09-10-2013', '09-12-2013', '14-09-2013',
#        '16-09-2013', '18-09-2013', '20-09-2013', '22-09-2013', '24-09-2013',
#        '26/9/2013', '28/9/2013', '30/9/2013', '10-02-2013', '10-04-2013',
#        '10-06-2013', '10-08-2010', '10-10-2013', '10-12-2013', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35'],
#       dtype='object')

# %%
df1['Unnamed: 26'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 495    True
# 496    True
# 497    True
# 498    True
# 499    True
# Name: Unnamed: 26, Length: 500, dtype: bool

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[df['profit'] == max(df['profit'])]['customer_name'] #customer name having maximum profit
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
len(df[df['country']=='Sweden'])  #number of orders from Sweden
# Out:
# 203

# %%
df[df['shipping_cost']>20]  #shipment cost more than $40
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# ...                ...         ...         ...             ...
# 51241  ES-2014-3638865  12/31/2014    1/1/2015     First Class
# 51242   MX-2014-141712  12/31/2014  12/31/2014        Same Day
# 51243    IN-2014-78627  12/31/2014    1/4/2015  Standard Class
# 51244  IT-2014-3715679  12/31/2014    1/5/2015    Second Class
# 51245    IN-2014-75603  12/31/2014    1/5/2015    Second Class
#
#           customer_name      segment            state         country  market  \
# 0       Toby Braunhardt     Consumer      Constantine         Algeria  Africa
# ...

# %%
df[df['shipping_cost']>80] #shipment cost more than $80
# Out:
#              order_id  order_date ship_date       ship_mode  \
# 7       IN-2011-79397    1/3/2011  1/3/2011        Same Day
# 8       ID-2011-80230    1/3/2011  1/9/2011  Standard Class
# 9        IZ-2011-4680    1/3/2011  1/7/2011  Standard Class
# 27     MX-2011-111255    1/4/2011  1/9/2011    Second Class
# 43     MX-2011-109267    1/5/2011  1/9/2011  Standard Class
# ...               ...         ...       ...             ...
# 51154   IN-2014-49206  12/30/2014  1/1/2015    Second Class
# 51228  MX-2014-116267  12/31/2014  1/3/2015    Second Class
# 51229   IN-2014-43550  12/31/2014  1/1/2015     First Class
# 51230    RS-2014-1460  12/31/2014  1/2/2015    Second Class
# 51231   IN-2014-30390  12/31/2014  1/3/2015     First Class
#
#              customer_name    segment            state      country market  \
# 7              Kean Nguyen  Corporate  New South Wales    Australia   APAC
# 8             Ken Lonsdale   Consumer         Auckland  New Zealand   APAC
# ...

# %%
df[df['shipping_cost']>80]['country']
# Out:
# 7          Australia
# 8        New Zealand
# 9               Iraq
# 27            Brazil
# 43            Mexico
#             ...
# 51154      Indonesia
# 51228         Brazil
# 51229      Indonesia
# 51230         Russia
# 51231       Thailand
# Name: country, Length: 3984, dtype: object

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
# ...

# %%
df[(df['shipping_cost']>100) & (df['profit']<10)]#shipment_cost>100 and profit<100
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# category1          object
# dtype: object

# %%
date = pd.to_datetime(df['order_date'])

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converteded_order_date'] =  pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_year'] = df['converteded_order_date'].dt.year

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_month'] = df['converteded_order_date'].dt.month

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... quantity  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...        2
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...        3
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...        4
# 3  Home Office        Stockholm     Sweden      EU    North  ...        3
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...        5
#
#   discount   profit shipping_cost order_priority  year  category1  \
# ...

# %%
df['order_date_week'] = df['converteded_order_date'].dt.week
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_1704\4241230342.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['order_date_week'] = df['converteded_order_date'].dt.week

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# ...

# %%
df[['converteded_order_date','order_date_week']]
# Out:
#       converteded_order_date  order_date_week
# 0                 2011-01-01               52
# 1                 2011-01-01               52
# 2                 2011-01-01               52
# 3                 2011-01-01               52
# 4                 2011-01-01               52
# ...                      ...              ...
# 51285             2014-12-31                1
# 51286             2014-12-31                1
# 51287             2014-12-31                1
# 51288             2014-12-31                1
# 51289             2014-12-31                1
#
# [51290 rows x 2 columns]

# %%
df[df['order_date_year'] == 2014]  #data for 2014 year
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  1/3/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  1/5/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  1/3/2014    Second Class
# 33762   US-2014-105830    1/1/2014  1/3/2014     First Class
# 33763   CA-2014-160395    1/1/2014  1/7/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# ...

# %%
df['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'converteded_order_date', 'order_date_year',
#        'order_date_month', 'order_date_week'],
#       dtype='object')

# %%
df['cost_to_company'] = df['shipping_cost'] + df['discount']

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   36.036
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
#
#   shipping_cost order_priority  year category1  converteded_order_date  \
# ...

# %%
df[df['cost_to_company'] == max(df['cost_to_company'])]['product_name']
# Out:
# 13891    Plantronics CS510 - Over-the-Head monaural Wir...
# Name: product_name, dtype: object

# %%
df.drop('category1',axis= 1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.drop("cost_to_company",axis=1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   profit  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...  106.140
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...   36.036
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm     Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...   37.770
#
#   shipping_cost order_priority  year category1  converteded_order_date  \
# ...

# %%
df.drop("cost_to_company",axis=1,inplace = True)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.drop(1,inplace= True)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.loc[[2,3]]  #for filtering rows
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ... discount  profit  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...      0.0  29.640
# 3  Home Office  Stockholm   Sweden     EU  North  ...      0.5 -26.055
#
#   shipping_cost order_priority  year  category1  converteded_order_date  \
# 2          8.17           High  2011     prince              2011-01-01
# 3          4.82           High  2011     prince              2011-01-01
#
#    order_date_year  order_date_month order_date_week
# 2             2011                 1              52
# 3             2011                 1              52
#
# [2 rows x 26 columns]

# %%
df.loc[2:11:2]
# Out:
#          order_id order_date ship_date       ship_mode    customer_name  \
# 2    HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 4   IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 6    CA-2011-1510   1/2/2011  1/6/2011  Standard Class  Magdelene Morse
# 8   ID-2011-80230   1/3/2011  1/9/2011  Standard Class     Ken Lonsdale
# 10  IN-2011-65159   1/3/2011  1/7/2011    Second Class     Larry Blacks
#
#      segment             state      country  market          region  ...  \
# 2   Consumer          Budapest      Hungary    EMEA            EMEA  ...
# 4   Consumer   New South Wales    Australia    APAC         Oceania  ...
# 6   Consumer           Ontario       Canada  Canada          Canada  ...
# 8   Consumer          Auckland  New Zealand    APAC         Oceania  ...
# 10  Consumer  National Capital  Philippines    APAC  Southeast Asia  ...
#
#    discount    profit shipping_cost order_priority  year  category1  \
# ...

# %%
    df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.head(4)
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# 0  106.140         35.46         Medium  2011     prince
# 2   29.640          8.17           High  2011     prince
# ...

# %%
df.loc[:4]
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  \
# 0  106.140         35.46         Medium  2011     prince
# 2   29.640          8.17           High  2011     prince
# ...

# %%
df.loc[0:4,['order_id','order_date','ship_date']]  #based on named location
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
# 4    IN-2011-47883   1/1/2011  1/8/2011

# %%
df.iloc[0:4,0:4]  #based on internal index
# Out:
#           order_id order_date ship_date       ship_mode
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class

# %%
df.iloc[1:5,3:6]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
df.loc[1:5,['ship_mode','customer_name','segment']]
# Out:
#         ship_mode  customer_name      segment
# 2    Second Class  Annie Thurman     Consumer
# 3    Second Class   Eugene Moren  Home Office
# 4  Standard Class    Joseph Holt     Consumer
# 5  Standard Class    Joseph Holt     Consumer

# %%
df2 = df[df.dtypes[(df.dtypes=='float64') |( df.dtypes=='int64' )].index]

# %%
df.dtypes[df.dtypes!='object']
# Out:
# quantity                           int64
# discount                         float64
# profit                           float64
# shipping_cost                    float64
# year                               int64
# converteded_order_date    datetime64[ns]
# order_date_year                    int64
# order_date_month                   int64
# order_date_week                    int64
# dtype: object

# %%
df2
# Out:
#        quantity  discount    profit  shipping_cost  year  order_date_year  \
# 0             2       0.0  106.1400          35.46  2011             2011
# 2             4       0.0   29.6400           8.17  2011             2011
# 3             3       0.5  -26.0550           4.82  2011             2011
# 4             5       0.1   37.7700           4.70  2011             2011
# 5             2       0.1   15.3420           1.80  2011             2011
# ...         ...       ...       ...            ...   ...              ...
# 51285         2       0.2    4.5188           0.89  2014             2014
# 51286         1       0.0    0.4200           0.49  2014             2014
# 51287         3       0.0   12.3600           0.35  2014             2014
# 51288         1       0.0    0.5600           0.20  2014             2014
# 51289         3       0.2   -0.6048           0.17  2014             2014
#
#        order_date_month  order_date_week
# ...

# %%
df2[df2>100]   #filtering values more than 100
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
df3 = df2[df2>100]

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year, order_date_year, order_date_month, order_date_week]
# Index: []

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# 5           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
df3.dropna(thresh = 3)
# Out:
#        quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.140            NaN  2011             2011
# 7           NaN       NaN  110.412         125.32  2011             2011
# 8           NaN       NaN      NaN         107.10  2011             2011
# 9           NaN       NaN  253.320            NaN  2011             2011
# 12          NaN       NaN  290.430            NaN  2011             2011
# ...         ...       ...      ...            ...   ...              ...
# 51234       NaN       NaN  216.720            NaN  2014             2014
# 51236       NaN       NaN  180.240            NaN  2014             2014
# 51245       NaN       NaN  105.000            NaN  2014             2014
# 51252       NaN       NaN  166.440            NaN  2014             2014
# 51269       NaN       NaN  153.090            NaN  2014             2014
#
#        order_date_month  order_date_week
# 0                   NaN              NaN
# ...

# %%
df3.fillna(value = 4)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           4.0       4.0  106.14            4.0  2011             2011
# 2           4.0       4.0    4.00            4.0  2011             2011
# 3           4.0       4.0    4.00            4.0  2011             2011
# 4           4.0       4.0    4.00            4.0  2011             2011
# 5           4.0       4.0    4.00            4.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       4.0       4.0    4.00            4.0  2014             2014
# 51286       4.0       4.0    4.00            4.0  2014             2014
# 51287       4.0       4.0    4.00            4.0  2014             2014
# 51288       4.0       4.0    4.00            4.0  2014             2014
# 51289       4.0       4.0    4.00            4.0  2014             2014
#
#        order_date_month  order_date_week
# 0                   4.0              4.0
# ...

# %%
df3['quantity'].fillna(value = df3['profit'].mean())
# Out:
# 0        285.710477
# 2        285.710477
# 3        285.710477
# 4        285.710477
# 5        285.710477
#             ...
# 51285    285.710477
# 51286    285.710477
# 51287    285.710477
# 51288    285.710477
# 51289    285.710477
# Name: quantity, Length: 51289, dtype: float64

# %%
df3['quantity'].mean()
# Out:
# nan

# %%
df3.fillna(value = df3['profit'].mean())
# Out:
#          quantity    discount      profit  shipping_cost  year  \
# 0      285.710477  285.710477  106.140000     285.710477  2011
# 2      285.710477  285.710477  285.710477     285.710477  2011
# 3      285.710477  285.710477  285.710477     285.710477  2011
# 4      285.710477  285.710477  285.710477     285.710477  2011
# 5      285.710477  285.710477  285.710477     285.710477  2011
# ...           ...         ...         ...            ...   ...
# 51285  285.710477  285.710477  285.710477     285.710477  2014
# 51286  285.710477  285.710477  285.710477     285.710477  2014
# 51287  285.710477  285.710477  285.710477     285.710477  2014
# 51288  285.710477  285.710477  285.710477     285.710477  2014
# 51289  285.710477  285.710477  285.710477     285.710477  2014
#
#        order_date_year  order_date_month  order_date_week
# 0                 2011        285.710477       285.710477
# 2                 2011        285.710477       285.710477
# ...

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.groupby("order_date_year")['profit'].mean()
# Out:
# order_date_year
# 2011    27.665308
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.groupby("order_date_year")['discount'].mean()
# Out:
# order_date_year
# 2011    0.148193
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
df.groupby("order_date_year")[['discount','profit']].mean()
# Out:
#                  discount     profit
# order_date_year
# 2011             0.148193  27.665308
# 2012             0.141286  28.043722
# 2013             0.140265  29.604519
# 2014             0.143291  28.758540

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'converteded_order_date', 'order_date_year',
#        'order_date_month', 'order_date_week'],
#       dtype='object')

# %%
df[['country','market']]
# Out:
#              country  market
# 0            Algeria  Africa
# 2            Hungary    EMEA
# 3             Sweden      EU
# 4          Australia    APAC
# 5          Australia    APAC
# ...              ...     ...
# 51285  United States      US
# 51286        Morocco  Africa
# 51287      Nicaragua   LATAM
# 51288         Mexico   LATAM
# 51289  United States      US
#
# [51289 rows x 2 columns]

# %%
df['sales']
# Out:
# 0        408
# 2         66
# 3         45
# 4        114
# 5         55
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51289, dtype: object

# %%
df['sales'] = df.sales.str.replace(",","")

# %%
df['sales'] = df.sales.astype(int)

# %%
df.dtypes
# Out:
# order_id                          object
# order_date                        object
# ship_date                         object
# ship_mode                         object
# customer_name                     object
# segment                           object
# state                             object
# country                           object
# market                            object
# region                            object
# product_id                        object
# category                          object
# sub_category                      object
# product_name                      object
# sales                              int32
# quantity                           int64
# discount                         float64
# profit                           float64
# shipping_cost                    float64
# order_priority                    object
# year                               int64
# category1                         object
# converteded_order_date    datetime64[ns]
# ...

# %%
df.groupby("order_date_year")['sales'].mean()
# Out:
# order_date_year
# 2011    251.127153
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64

# %%
df.groupby("order_date_year")['quantity'].sum()
# Out:
# order_date_year
# 2011    31440
# 2012    38111
# 2013    48136
# 2014    60622
# Name: quantity, dtype: int64

# %%
df.groupby("order_date_year")['sales'].sum()
# Out:
# order_date_year
# 2011    2259391
# 2012    2677493
# 2013    3405860
# 2014    4300041
# Name: sales, dtype: int32

# %%
df.drop('category1',axis= 1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
#Questions
1. Find out there average ratings on a weekly basis,keep this in mind that they take 2 days off
2.Total working days for each agents
3.Total queries that has been solved/taken
4.Total feedback received
5.agent name who have average rating between 3.5 to 4
6.Agent name who have rating less than 3.5
7.Agent rating who have more than 4.5
8.How many feedback agents have received more than 4.5 average
9.average weekly response time for each agent
10.average weekly resolution time for each agents
11.list of all agents name 
12.percentage of chat on which they have received a feedback
13.Total contribution hour for each and every agents on weekly basis
14.Total percentage of active hour for a month

# %%
df= pd.read_csv(r"C:\Users\Prince\Downloads\AgentPerformance.csv")

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.Date
# Out:
# 0      2022-07-30
# 1      2022-07-30
# 2      2022-07-30
# 3      2022-07-30
# 4      2022-07-30
#           ...
# 2155   2022-07-01
# 2156   2022-07-01
# 2157   2022-07-01
# 2158   2022-07-01
# 2159   2022-07-01
# Name: Date, Length: 2160, dtype: datetime64[ns]

# %%
df['week'] = df["Date"].dt.week
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_1704\1750264959.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week'] = df["Date"].dt.week

# %%
df
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1 2022-07-30        Prerna Singh           11               0:00:38
# 1         2 2022-07-30       Nandani Gupta           11               0:01:15
# 2         3 2022-07-30          Ameya Jain           14               0:00:30
# 3         4 2022-07-30       Mahesh Sarade           14               0:01:04
# 4         5 2022-07-30              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156 2022-07-01   Sowmiya Sivakumar            0               0:00:00
# 2156   2157 2022-07-01             Nitin M            0               0:00:00
# 2157   2158 2022-07-01              Vivek             0               0:00:00
# 2158   2159 2022-07-01       Ayushi Mishra            0               0:00:00
# 2159   2160 2022-07-01  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df1 = df[df['Total Chats']>0]  #creating new dataframe of agents who have not attended any chats

# %%
df1
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1 2022-07-30        Prerna Singh           11               0:00:38
# 1         2 2022-07-30       Nandani Gupta           11               0:01:15
# 2         3 2022-07-30          Ameya Jain           14               0:00:30
# 3         4 2022-07-30       Mahesh Sarade           14               0:01:04
# 4         5 2022-07-30              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2101   2102 2022-07-01       Jaydeep Dixit           25               0:01:15
# 2102   2103 2022-07-01  Shivananda Sonwane           23               0:01:24
# 2103   2104 2022-07-01      Khushboo Priya           24               0:01:46
# 2104   2105 2022-07-01     Hrisikesh Neogi           15               0:01:05
# 2105   2106 2022-07-01              Tarun            22               0:00:00
#
# ...

# %%
df1.groupby(["week","Agent Name"])['Average Rating'].mean()
# Out:
# week  Agent Name
# 26    Aditya Shinde          3.850
#       Ayushi Mishra          4.330
#       Bharath                4.835
#       Boktiar Ahmed Bappy    4.720
#       Deepranjan Gupta       4.230
#                              ...
# 30    Sowmiya Sivakumar      4.172
#       Suraj S Bilgi          4.680
#       Swati                  4.065
#       Wasim                  4.298
#       Zeeshan                4.140
# Name: Average Rating, Length: 182, dtype: float64

# %%
# Question 2 Total working days for each agents
df1.groupby(['Agent Name'])['Agent Name'].count()
# Out:
# Agent Name
# Aditya Shinde             12
# Aditya_iot                17
# Ameya Jain                15
# Anirudh                    7
# Ankitjha                   3
# Anurag Tiwari              2
# Aravind                   14
# Ashad Nasim                2
# Ayushi Mishra             24
# Bharath                   19
# Boktiar Ahmed Bappy       26
# Chaitra K Hiremath         6
# Deepranjan Gupta          21
# Dibyanshu                  1
# Harikrishnan Shaji        19
# Hitesh Choudhary           1
# Hrisikesh Neogi           21
# Ishawant Kumar            24
# Jawala Prakash            25
# Jayant Kumar               8
# Jaydeep Dixit             21
# Khushboo Priya            26
# Madhulika G               24
# Mahak                      1
# Mahesh Sarade             18
# Maitry                    20
# Maneesh                    3
# Manjunatha A              25
# Mithun S                  18
# Mukesh                     2
# Mukesh Rao                 3
# ...

# %%
#3.Total queries that has been solved/taken
df1.groupby(['Agent Name'])['Total Chats'].sum()
# Out:
# Agent Name
# Aditya Shinde             277
# Aditya_iot                231
# Ameya Jain                322
# Anirudh                    81
# Ankitjha                    5
# Anurag Tiwari               4
# Aravind                   366
# Ashad Nasim                18
# Ayushi Mishra             514
# Bharath                   369
# Boktiar Ahmed Bappy       452
# Chaitra K Hiremath         64
# Deepranjan Gupta          493
# Dibyanshu                   1
# Harikrishnan Shaji        381
# Hitesh Choudhary            1
# Hrisikesh Neogi           578
# Ishawant Kumar            338
# Jawala Prakash            439
# Jayant Kumar              127
# Jaydeep Dixit             512
# Khushboo Priya            446
# Madhulika G               469
# Mahak                       7
# Mahesh Sarade             364
# Maitry                    542
# Maneesh                     4
# Manjunatha A              413
# Mithun S                  503
# Mukesh                     19
# ...

# %%
#4.Total feedback received
df1.groupby(['Agent Name'])['Total Feedback'].sum()
# Out:
# Agent Name
# Aditya Shinde             153
# Aditya_iot                131
# Ameya Jain                228
# Anirudh                    39
# Ankitjha                    3
# Anurag Tiwari               3
# Aravind                   233
# Ashad Nasim                 9
# Ayushi Mishra             329
# Bharath                   247
# Boktiar Ahmed Bappy       311
# Chaitra K Hiremath         37
# Deepranjan Gupta          312
# Dibyanshu                   0
# Harikrishnan Shaji        231
# Hitesh Choudhary            0
# Hrisikesh Neogi           367
# Ishawant Kumar            202
# Jawala Prakash            250
# Jayant Kumar               70
# Jaydeep Dixit             305
# Khushboo Priya            289
# Madhulika G               281
# Mahak                       5
# Mahesh Sarade             216
# Maitry                    347
# Maneesh                     3
# Manjunatha A              254
# Mithun S                  364
# Mukesh                     17
# ...

# %%
#5.agent name who have average rating between 3.5 to 4
df2 = df1.groupby(['Agent Name'])

# %%
average_rating = df2['Average Rating'].mean()

# %%
average_rating
# Out:
# Agent Name
# Aditya Shinde             4.500833
# Aditya_iot                4.138824
# Ameya Jain                4.439333
# Anirudh                   2.764286
# Ankitjha                  2.666667
# Anurag Tiwari             2.750000
# Aravind                   4.674286
# Ashad Nasim               2.500000
# Ayushi Mishra             4.352500
# Bharath                   4.711053
# Boktiar Ahmed Bappy       4.116923
# Chaitra K Hiremath        4.323333
# Deepranjan Gupta          4.123810
# Dibyanshu                 0.000000
# Harikrishnan Shaji        4.167895
# Hitesh Choudhary          0.000000
# Hrisikesh Neogi           4.480476
# Ishawant Kumar            4.429167
# Jawala Prakash            4.166400
# Jayant Kumar              4.007500
# Jaydeep Dixit             4.524286
# Khushboo Priya            4.273462
# Madhulika G               4.373333
# Mahak                     3.000000
# Mahesh Sarade             4.000556
# Maitry                    4.390500
# ...

# %%
average_rating[(average_rating>=3.5) & (average_rating<=4)]
# Out:
# Agent Name
# Mithun S    3.931667
# Shivan K    3.874545
# Name: Average Rating, dtype: float64

# %%
#6.Agent name who have rating less than 3.5
average_rating[average_rating<3.5].sort_values()
# Out:
# Agent Name
# Dibyanshu           0.000000
# Hitesh Choudhary    0.000000
# Samprit             0.000000
# Tarun               1.500000
# Maneesh             1.666667
# Ashad Nasim         2.500000
# Mukesh Rao          2.556667
# Ankitjha            2.666667
# Anurag Tiwari       2.750000
# Anirudh             2.764286
# Mahak               3.000000
# Vivek               3.004000
# Name: Average Rating, dtype: float64

# %%
#7.Agent rating who have more than 4.5
average_rating[average_rating>=4.5].sort_values()
# Out:
# Agent Name
# Wasim                 4.500000
# Aditya Shinde         4.500833
# Jaydeep Dixit         4.524286
# Shivananda Sonwane    4.535000
# Saikumarreddy N       4.570000
# Shubham Sharma        4.607619
# Mukesh                4.645000
# Aravind               4.674286
# Suraj S Bilgi         4.680000
# Bharath               4.711053
# Sudhanshu Kumar       5.000000
# Name: Average Rating, dtype: float64

# %%
#8.How many feedback agents have received more than 4.5 average
average_rating[average_rating>=4.5].index
# Out:
# Index(['Aditya Shinde', 'Aravind ', 'Bharath ', 'Jaydeep Dixit', 'Mukesh ',
#        'Saikumarreddy N', 'Shivananda Sonwane', 'Shubham Sharma',
#        'Sudhanshu Kumar', 'Suraj S Bilgi', 'Wasim '],
#       dtype='object', name='Agent Name')

# %%
['Aditya Shinde', 'Aravind ', 'Bharath ', 'Jaydeep Dixit', 'Mukesh ',
       'Saikumarreddy N', 'Shivananda Sonwane', 'Shubham Sharma',
       'Sudhanshu Kumar', 'Suraj S Bilgi', 'Wasim ']

# %%
df1 =df[df['Total Chats']>0]

# %%
df1.set_index("Agent Name",inplace = True)

# %%
df4 = df1.loc[['Aditya Shinde', 'Aravind ', 'Bharath ', 'Jaydeep Dixit', 'Mukesh ',
       'Saikumarreddy N', 'Shivananda Sonwane', 'Shubham Sharma',
       'Sudhanshu Kumar', 'Suraj S Bilgi', 'Wasim ']]

# %%
df4.groupby(['Agent Name'])["Total Chats"].sum()
# Out:
# Agent Name
# Aditya Shinde         277
# Aravind               366
# Bharath               369
# Jaydeep Dixit         512
# Mukesh                 19
# Saikumarreddy N       364
# Shivananda Sonwane    441
# Shubham Sharma        510
# Sudhanshu Kumar         2
# Suraj S Bilgi          28
# Wasim                 433
# Name: Total Chats, dtype: int64

# %%
#12.percentage of chat on which they have received a feedback
df1.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11   2023-08-17 00:00:38
# 1      2 2022-07-30  Nandani Gupta           11   2023-08-17 00:01:15
# 2      3 2022-07-30     Ameya Jain           14   2023-08-17 00:00:30
# 3      4 2022-07-30  Mahesh Sarade           14   2023-08-17 00:01:04
# 4      5 2022-07-30         Swati            14   2023-08-17 00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback  week
# 0     2023-08-17 00:04:20            4.11               9    30
# 1     2023-08-17 00:28:25            3.14               7    30
# 2     2023-08-17 00:11:36            4.55              11    30
# 3     2023-08-17 00:15:46            4.71               7    30
# 4     2023-08-17 00:16:33            3.67               6    30

# %%
#9.average weekly response time for each agent
df1.groupby(['Agent Name','week'])[['Average Response Time']].mean()
# Out:
#                            Average Response Time
# Agent Name    week
# Aditya Shinde 26   2023-08-17 00:01:23.000000000
#               27   2023-08-17 00:01:06.200000000
#               28   2023-08-17 00:01:19.000000000
# Aditya_iot    27   2023-08-17 00:01:10.500000000
#               28   2023-08-17 00:01:12.800000000
# ...                                          ...
# Wasim         30   2023-08-17 00:01:00.600000000
# Zeeshan       27   2023-08-17 00:01:22.500000000
#               28   2023-08-17 00:02:52.800000000
#               29   2023-08-17 00:01:28.000000000
#               30   2023-08-17 00:01:35.750000128
#
# [182 rows x 1 columns]

# %%
df1
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1 2022-07-30        Prerna Singh           11               0:00:38
# 1         2 2022-07-30       Nandani Gupta           11               0:01:15
# 2         3 2022-07-30          Ameya Jain           14               0:00:30
# 3         4 2022-07-30       Mahesh Sarade           14               0:01:04
# 4         5 2022-07-30              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2101   2102 2022-07-01       Jaydeep Dixit           25               0:01:15
# 2102   2103 2022-07-01  Shivananda Sonwane           23               0:01:24
# 2103   2104 2022-07-01      Khushboo Priya           24               0:01:46
# 2104   2105 2022-07-01     Hrisikesh Neogi           15               0:01:05
# 2105   2106 2022-07-01              Tarun            22               0:00:00
#
# ...

# %%
df1['Average Response Time'] = pd.to_datetime(df1['Average Response Time'])
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_1704\2025404757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Average Response Time'] = pd.to_datetime(df1['Average Response Time'])

# %%
df1.dtypes
# Out:
# SL No                               int64
# Date                       datetime64[ns]
# Agent Name                         object
# Total Chats                         int64
# Average Response Time      datetime64[ns]
# Average Resolution Time    datetime64[ns]
# Average Rating                    float64
# Total Feedback                      int64
# week                                int64
# dtype: object

# %%
#10.average weekly resolution time for each agents
df1['Average Resolution Time'] = pd.to_datetime(df1['Average Resolution Time'])
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_1704\348375814.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Average Resolution Time'] = pd.to_datetime(df1['Average Resolution Time'])

# %%
df1.groupby(['Agent Name','week'])[['Average Resolution Time']].mean()
# Out:
#                          Average Resolution Time
# Agent Name    week
# Aditya Shinde 26   2023-08-17 00:23:10.500000000
#               27   2023-08-17 00:21:05.400000000
#               28   2023-08-17 00:31:42.200000000
# Aditya_iot    27   2023-08-17 00:18:04.500000000
#               28   2023-08-17 00:21:15.400000000
# ...                                          ...
# Wasim         30   2023-08-17 00:21:05.800000000
# Zeeshan       27   2023-08-17 00:18:50.500000000
#               28   2023-08-17 00:22:58.000000000
#               29   2023-08-17 00:18:32.000000000
#               30   2023-08-17 00:19:20.249999872
#
# [182 rows x 1 columns]

# %%
#11.list of all agents name 
df['Agent Name'].unique()
# Out:
# array(['Prerna Singh', 'Nandani Gupta', 'Ameya Jain', 'Mahesh Sarade',
#        'Swati ', 'Mukesh ', 'Saikumarreddy N', 'Sanjeev Kumar',
#        'Shubham Sharma', 'Nishtha Jain', 'Manjunatha A', 'Khushboo Priya',
#        'Suraj S Bilgi', 'Harikrishnan Shaji', 'Hrisikesh Neogi',
#        'Shivan K', 'Sowmiya Sivakumar', 'Madhulika G', 'Mithun S',
#        'Hitesh Choudhary', 'Sanjeevan ', 'Anirudh ', 'Shiva Srivastava',
#        'Dibyanshu ', 'Ashish ', 'Uday Mishra', 'Aditya Shinde',
#        'Jayant Kumar', 'Aditya_iot ', 'Prabir Kumar Satapathy',
#        'Saurabh Shukla', 'Wasim ', 'Samprit ', 'Maitry ', 'Abhishek ',
#        'Rishav Dash', 'Aravind ', 'Tarun ', 'Muskan Garg', 'Ankit Sharma',
#        'Bharath ', 'Ashad Nasim', 'Vasanth P', 'Aditya ', 'Amersh ',
#        'Sandipan Saha', 'Ineuron Intelligence ', 'Mahak ', 'Mukesh Rao ',
#        'Zeeshan ', 'Anurag Tiwari', 'Ankitjha ', 'Saif Khan',
#        'Jaydeep Dixit', 'Sudhanshu Kumar', 'Maneesh ', 'Hyder Abbas',
# ...

# %%
#12.percentage of chat on which they have received a feedback
df1.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11   2023-08-17 00:00:38
# 1      2 2022-07-30  Nandani Gupta           11   2023-08-17 00:01:15
# 2      3 2022-07-30     Ameya Jain           14   2023-08-17 00:00:30
# 3      4 2022-07-30  Mahesh Sarade           14   2023-08-17 00:01:04
# 4      5 2022-07-30         Swati            14   2023-08-17 00:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback  week
# 0     2023-08-17 00:04:20            4.11               9    30
# 1     2023-08-17 00:28:25            3.14               7    30
# 2     2023-08-17 00:11:36            4.55              11    30
# 3     2023-08-17 00:15:46            4.71               7    30
# 4     2023-08-17 00:16:33            3.67               6    30

# %%
df3 = df1.groupby(['Agent Name'])['Total Chats','Total Feedback'].sum()
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_1704\366162775.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df3 = df1.groupby(['Agent Name'])['Total Chats','Total Feedback'].sum()

# %%
df3
# Out:
#                         Total Chats  Total Feedback
# Agent Name
# Aditya Shinde                   277             153
# Aditya_iot                      231             131
# Ameya Jain                      322             228
# Anirudh                          81              39
# Ankitjha                          5               3
# Anurag Tiwari                     4               3
# Aravind                         366             233
# Ashad Nasim                      18               9
# Ayushi Mishra                   514             329
# Bharath                         369             247
# Boktiar Ahmed Bappy             452             311
# Chaitra K Hiremath               64              37
# Deepranjan Gupta                493             312
# Dibyanshu                         1               0
# Harikrishnan Shaji              381             231
# Hitesh Choudhary                  1               0
# Hrisikesh Neogi                 578             367
# ...

# %%
df3['percentage']= (df3['Total Feedback'])/(df3['Total Chats'])*100

# %%
df3.sort_values(by = 'percentage')
# Out:
#                         Total Chats  Total Feedback  percentage
# Agent Name
# Samprit                           1               0    0.000000
# Hitesh Choudhary                  1               0    0.000000
# Dibyanshu                         1               0    0.000000
# Tarun                            22               6   27.272727
# Vivek                            44              20   45.454545
# Anirudh                          81              39   48.148148
# Saurabh Shukla                   16               8   50.000000
# Ashad Nasim                      18               9   50.000000
# Suraj S Bilgi                    28              15   53.571429
# Nandani Gupta                   560             308   55.000000
# Jayant Kumar                    127              70   55.118110
# Aditya Shinde                   277             153   55.234657
# Prateek _iot                    190             107   56.315789
# ...

# %%
#13.Total contribution hour for each and every agents on weekly basis
Login = pd.read_csv(r"C:\Users\Prince\Downloads\AgentLogingReport.csv")

# %%
Login
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
Login.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
Login['Login Time'] = pd.to_datetime(Login['Login Time'])

# %%
Login['Date'] = pd.to_datetime(Login['Date'])

# %%
Login['Logout Time'] = pd.to_datetime(Login['Logout Time'])

# %%
Login['Duration']= pd.to_datetime(Login['Duration'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File ~\anaconda3\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\_libs\tslib.pyx:605, in pandas._libs.tslib.array_to_datetime()
#
# ...

# %%
Login['week'] = Login['Date'].dt.week
# Out:
# C:\Users\Prince\AppData\Local\Temp\ipykernel_1704\2568411634.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   Login['week'] = Login['Date'].dt.week

# %%
Login.groupby(['Agent','week'])['Duration'].sum()
# Out:
# Agent          week
# Aditya Shinde  30                                               00:02:10
# Aditya_iot     29                               01:57:3102:06:4602:01:26
#                30       02:12:0500:49:4600:04:2002:14:4301:57:4702:19:28
# Amersh         30                       00:02:4002:54:5200:05:2900:00:49
# Ameya Jain     29      00:44:4000:07:2404:01:1001:57:5906:00:5704:37:...
#                                              ...
# Tarun          26                                              514:08:20
# Wasim          29      00:00:5500:02:0005:32:3000:05:3006:03:0000:00:...
#                30      07:19:5000:02:2006:12:0705:24:0500:01:5003:45:...
# Zeeshan        29       06:05:2700:01:0200:27:4205:39:2606:08:5106:03:11
#                30                       06:12:5006:03:1206:03:0106:20:37
# Name: Duration, Length: 89, dtype: object
